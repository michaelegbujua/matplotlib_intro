# %% [markdown]
# the matplotlib is a library inside of pyplot package, it is used for data visualisation

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
new_data = np.arange(9)

# %%
# %matplotlib notebook

# %%
# %matplotlib inline

# %%
plt.plot(new_data)
plt.title('The new graph')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
# Out:
# Text(0, 0.5, 'y-axis')

# %%
x = [1, 2, 3, 4, 5, 6, 7]
y = [1, 4, 9, 16, 25, 36, 49]

# %%
plt.plot(x,y)
plt.title("Charles' Law: graph of Temp Vs Pressure")
plt.xlabel('temperature')
plt.ylabel('Pressure')
# Out:
# Text(0, 0.5, 'Pressure')

# %% [markdown]
# ## Bar Chart

# %%
new_films = ['film1', 'film2', 'film3', 'film4']
awards = [3, 9, 1,5]

# %%
plt.bar(range(len(new_films)), awards)

plt.xticks(range(len(new_films)), new_films)
plt.title('the top films')
plt.ylabel("No of Awards")
# Out:
# Text(0, 0.5, 'No of Awards')

# %% [markdown]
# ## Using Histogram

# %% [markdown]
# Histogram is used to show data in frequency distribution

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
new_h = np.random.normal(150, 15, 230)

# %%
plt.hist(new_h)
# Out:
# (array([ 4.,  6., 18., 41., 44., 37., 44., 19., 10.,  7.]),
#  array([114.90871174, 121.66287717, 128.41704259, 135.17120801,
#         141.92537343, 148.67953885, 155.43370428, 162.1878697 ,
#         168.94203512, 175.69620054, 182.45036596]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## pie chart

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array([37, 27, 27, 17])
ch_labels = ['first', 'second', 'third', 'fourth']
plt.pie(x, labels =ch_labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x18fd0a97fd0>,
#   <matplotlib.patches.Wedge at 0x18fd0aa54f0>,
#   <matplotlib.patches.Wedge at 0x18fd0aa5970>,
#   <matplotlib.patches.Wedge at 0x18fd0aa5df0>],
#  [Text(0.5220603932925612, 0.9682215375394293, 'first'),
#   Text(-1.077274690112854, 0.22243929968028323, 'second'),
#   Text(-0.22243929968028328, -1.0772746901128538, 'third'),
#   Text(0.9682215375394291, -0.5220603932925618, 'fourth')])
